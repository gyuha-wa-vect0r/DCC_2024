# %%
import os
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from PIL import Image
import json

# 경로 설정
training_image_path = "/home/gyuha_lee/DCC2024/dataset/bg_remove/rembg/90/training_image_no_bg"
validation_image_path = "/home/gyuha_lee/DCC2024/dataset/bg_remove/rembg/90/validation_image_no_bg"
model_path = "/home/gyuha_lee/DCC2024/mission1/WITHOUT_PRETRAINED/resnet18_gender_style_pretrained.pth"
json_path = "/home/gyuha_lee/DCC2024/mission2/top_100_preference.json"

# ResNet-18 모델 로드 및 학습된 가중치 불러오기
model = models.resnet18(pretrained=False)
model.fc = nn.Identity()  # 마지막 FC 레이어를 제거하여 중간 레이어의 feature vector를 추출하도록 설정
model.load_state_dict(torch.load(model_path), strict=False)  # 가중치 로드
model.eval()  # 모델을 평가 모드로 전환

# 이미지 전처리 설정
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 특징 벡터 추출 함수 정의
def extract_feature_vector(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # 배치 차원 추가
    with torch.no_grad():
        feature_vector = model(image).squeeze().numpy()  # 특징 벡터 추출
    return feature_vector
# Out:
# /home/gyuha_lee/miniconda3/envs/dcc2024/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/gyuha_lee/miniconda3/envs/dcc2024/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /tmp/ipykernel_169352/3860674976.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path), strict=False)  # 가중치 로드

# %%
# 특징 벡터 추출 함수 정의
def extract_feature_vector(image_path):
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # 배치 차원 추가
    with torch.no_grad():
        feature_vector = model(image).squeeze().numpy()  # 특징 벡터 추출
    return feature_vector

# 모든 Training 이미지의 feature vector를 미리 추출하고 저장
training_features = []
training_labels = []

with open(json_path, 'r') as f:
    data = json.load(f)

# 2번 과정: Training 데이터의 특징 벡터 추출 및 저장
user_counter = 0
for user_id, user_data in data.items():
    user_counter += 1
    print(f"사용자 {user_counter}/{len(data)}의 Training 이미지 특징 벡터 추출 중...")
    
    # 선호 및 비선호 이미지 리스트
    training_preferred_files = user_data['Training']['선호']
    training_non_preferred_files = user_data['Training']['비선호']

    # 각 이미지를 통해 특징 벡터 추출 및 저장
    for img in training_preferred_files:
        feature = extract_feature_vector(os.path.join(training_image_path, img))
        training_features.append((feature, 1))  # (특징 벡터, 선호 레이블) 형태로 저장

    for img in training_non_preferred_files:
        feature = extract_feature_vector(os.path.join(training_image_path, img))
        training_features.append((feature, 0))  # (특징 벡터, 비선호 레이블) 형태로 저장

print("모든 Training 이미지의 특징 벡터 추출 완료.")
# Out:
# 사용자 1/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 2/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 3/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 4/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 5/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 6/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 7/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 8/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 9/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 10/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 11/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 12/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 13/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 14/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 15/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 16/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 17/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 18/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 19/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 20/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 21/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 22/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 23/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 24/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 25/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 26/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 27/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 28/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 29/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 30/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 31/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 32/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 33/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 34/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 35/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 36/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 37/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 38/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 39/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 40/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 41/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 42/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 43/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 44/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 45/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 46/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 47/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 48/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 49/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 50/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 51/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 52/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 53/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 54/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 55/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 56/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 57/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 58/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 59/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 60/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 61/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 62/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 63/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 64/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 65/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 66/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 67/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 68/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 69/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 70/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 71/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 72/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 73/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 74/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 75/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 76/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 77/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 78/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 79/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 80/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 81/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 82/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 83/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 84/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 85/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 86/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 87/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 88/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 89/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 90/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 91/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 92/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 93/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 94/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 95/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 96/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 97/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 98/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 99/100의 Training 이미지 특징 벡터 추출 중...
# 사용자 100/100의 Training 이미지 특징 벡터 추출 중...
# 모든 Training 이미지의 특징 벡터 추출 완료.

# %%
# 3번 과정: Validation 이미지에 대해 KNN 예측 수행
K = 5  # K 값 설정

results = []
user_counter = 0
for user_id, user_data in data.items():
    user_counter += 1
    print(f"사용자 {user_counter}/{len(data)}의 Validation 이미지 예측 중...")
    
    validation_files = user_data['Validation']['선호'] + user_data['Validation']['비선호']

    for val_img in validation_files:
        # 1. Validation 이미지의 특징 벡터 추출
        val_feature = extract_feature_vector(os.path.join(validation_image_path, val_img))

        # 2. 모든 Training 이미지와의 유사도 계산 (Validation 이미지 특징 벡터 사용)
        similarities = [cosine_similarity(val_feature.reshape(1, -1), train_feat.reshape(1, -1))[0][0] for train_feat, _ in training_features]

        # 3. 가장 유사한 K개의 인덱스 찾기
        top_k_indices = np.argsort(similarities)[-K:]

        # 4. K개의 가장 유사한 이미지들의 선호 여부를 통해 예측
        top_k_labels = [training_features[i][1] for i in top_k_indices]
        top_k_similarities = [similarities[i] for i in top_k_indices]

        # 가중치를 적용한 예측
        weighted_sum = sum(label * sim for label, sim in zip(top_k_labels, top_k_similarities))
        predicted_label = 1 if weighted_sum >= (sum(top_k_similarities) / 2) else 0

        true_label = 1 if val_img in user_data['Validation']['선호'] else 0

        # 결과 저장
        results.append({
            'user_id': user_id,
            'validation_file': val_img,
            'predicted_label': '선호' if predicted_label == 1 else '비선호',
            'true_label': '선호' if true_label == 1 else '비선호'
        })

        # 실시간 검증 결과 출력
        print(f"검증 결과 - 사용자: {user_id}, 파일: {val_img}, 예측: {'선호' if predicted_label == 1 else '비선호'}, 실제: {'선호' if true_label == 1 else '비선호'}")

print("모든 Validation 이미지에 대한 예측 완료.")
# Out:
# 사용자 1/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64747, 파일: W_46907_80_powersuit_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_44330_10_sportivecasual_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_39164_00_oriental_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_37491_70_military_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_20598_70_military_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_30988_90_kitsch_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_38588_19_genderless_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_22510_80_powersuit_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_05628_00_cityglam_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64747, 파일: W_34024_10_sportivecasual_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64747, 파일: W_14102_50_feminine_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64747, 파일: W_47169_70_hippie_W.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64747, 파일: W_02498_50_feminine_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64747, 파일: W_11610_90_grunge_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64747, 파일: W_27828_60_minimal_W.jpg, 예측: 비선호, 실제: 비선호
# 사용자 2/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 63405, 파일: W_01853_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_15294_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_02879_90_hiphop_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_02677_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_06860_19_normcore_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_04684_90_hiphop_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_04522_50_ivy_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 63405, 파일: W_16755_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63405, 파일: W_12304_80_bold_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 63405, 파일: W_12904_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63405, 파일: W_17443_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63405, 파일: W_16501_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63405, 파일: W_07187_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63405, 파일: W_15140_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 3/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64346, 파일: W_07316_00_metrosexual_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64346, 파일: W_24103_50_ivy_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64346, 파일: W_29990_90_hiphop_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64346, 파일: W_09154_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 
60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 35514, 파일: W_17559_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 35514, 파일: W_04349_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 35514, 파일: W_17796_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 48/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 60184, 파일: W_27765_60_mods_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60184, 파일: W_00004_50_ivy_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60184, 파일: W_25761_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_12744_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_19833_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_24590_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_12453_10_sportivecasual_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_24696_80_bold_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_29381_90_hiphop_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_27819_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60184, 파일: W_04245_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 49/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 60234, 파일: W_00842_10_sportivecasual_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 60234, 파일: W_02770_90_hiphop_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60234, 파일: W_02908_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60234, 파일: W_12789_00_metrosexual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60234, 파일: W_17413_00_metrosexual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60234, 파일: W_10107_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 60234, 파일: W_16698_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60234, 파일: W_16755_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60234, 파일: W_06786_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 50/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 60465, 파일: W_17747_80_bold_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60465, 파일: W_17623_19_normcore_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 60465, 파일: W_17221_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 60465, 파일: W_12615_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 60465, 파일: W_16819_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60465, 파일: W_12817_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 60465, 파일: W_06883_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60465, 파일: W_05868_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60465, 파일: W_12635_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 60465, 파일: W_16915_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 51/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 61250, 파일: W_28373_80_powersuit_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_29347_80_bodyconscious_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_34504_80_bodyconscious_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_01387_50_feminine_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_62253_19_lounge_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_44789_80_powersuit_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_10184_50_feminine_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_08913_10_athleisure_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_47408_80_powersuit_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_01933_50_feminine_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_65122_10_sportivecasual_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61250, 파일: W_34093_60_minimal_W.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 61250, 파일: W_20986_70_disco_W.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 61250, 파일: W_61790_10_sportivecasual_W.jpg, 예측: 선호, 실제: 비선호
# 사용자 52/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 28571, 파일: W_00073_50_ivy_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 28571, 파일: W_15716_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_15910_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_12128_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_16465_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_06576_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_16452_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_16247_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28571, 파일: W_17532_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 53/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 61493, 파일: W_09182_90_hiphop_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61493, 파일: W_03003_19_normcore_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61493, 파일: W_09277_10_sportivecasual_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61493, 파일: W_10107_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61493, 파일: W_17235_60_mods_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 61493, 파일: W_07290_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 61493, 파일: W_06715_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 61493, 파일: W_16247_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 61493, 파일: W_17787_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 61493, 파일: W_15701_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 61493, 파일: W_04463_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 61493, 파일: W_17062_19_normcore_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 61493, 파일: W_02728_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 사용자 54/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 28912, 파일: W_10103_19_normcore_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 28912, 파일: W_16375_80_bold_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 28912, 파일: W_00012_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 28912, 파일: W_04324_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28912, 파일: W_15440_70_hippie_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 28912, 파일: W_15295_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28912, 파일: W_01463_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 28912, 파일: W_15745_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 28912, 파일: W_06895_00_metrosexual_M.jpg, 예측: 선호, 실제: 비선호
# 사용자 55/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 20768, 파일: W_18373_50_classic_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 20768, 파일: W_10768_00_ecology_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 20768, 파일: W_13519_00_oriental_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자:
50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63910, 파일: W_16032_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63910, 파일: W_17333_19_normcore_M.jpg, 예측: 선호, 실제: 비선호
# 사용자 88/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 63927, 파일: W_05892_10_sportivecasual_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63927, 파일: W_06531_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63927, 파일: W_17603_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63927, 파일: W_17443_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63927, 파일: W_16516_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63927, 파일: W_09877_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 63927, 파일: W_04268_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 89/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 63930, 파일: W_07369_90_hiphop_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 63930, 파일: W_27854_50_ivy_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 63930, 파일: W_15762_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63930, 파일: W_17967_19_normcore_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63930, 파일: W_15497_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63930, 파일: W_16283_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63930, 파일: W_12866_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63930, 파일: W_16362_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 90/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 63934, 파일: W_17854_10_sportivecasual_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63934, 파일: W_02701_60_mods_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 63934, 파일: W_12897_10_sportivecasual_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63934, 파일: W_07018_19_normcore_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 63934, 파일: W_06788_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_12102_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_11163_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_17619_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_16747_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_15569_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_15684_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_17603_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_12342_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_17202_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 63934, 파일: W_15722_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 91/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64221, 파일: W_28453_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64221, 파일: W_10783_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64221, 파일: W_25086_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64221, 파일: W_28925_90_hiphop_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64221, 파일: W_16295_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64221, 파일: W_07333_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64221, 파일: W_15508_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64221, 파일: W_17747_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64221, 파일: W_26397_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64221, 파일: W_02936_00_metrosexual_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64221, 파일: W_12410_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 92/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64252, 파일: W_24152_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64252, 파일: W_23958_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_17304_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_30403_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_17478_19_normcore_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_12460_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_30290_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_10781_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64252, 파일: W_12708_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 93/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64280, 파일: W_12567_60_mods_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64280, 파일: W_24628_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64280, 파일: W_12530_90_hiphop_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64280, 파일: W_02688_60_mods_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64280, 파일: W_28022_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_27773_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_15740_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_27791_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_29251_10_sportivecasual_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_16393_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_24747_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_29942_50_ivy_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_29063_90_hiphop_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64280, 파일: W_01654_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 94/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64336, 파일: W_06557_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64336, 파일: W_24493_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64336, 파일: W_12635_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64336, 파일: W_12312_80_bold_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64336, 파일: W_12315_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64336, 파일: W_16172_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64336, 파일: W_25202_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 95/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64441, 파일: W_25790_90_hiphop_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64441, 파일: W_17783_80_bold_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64441, 파일: W_24517_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64441, 파일: W_16067_80_bold_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64441, 파일: W_17441_60_mods_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64441, 파일: W_25235_60_mods_M.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64441, 파일: W_24203_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64441, 파일: W_24883_00_metrosexual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64441, 파일: W_02820_00_metrosexual_M.jpg, 예측: 선호, 실제: 비선호
# 사용자 96/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64460, 파일: W_16732_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_23899_19_normcore_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_25715_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_25649_19_normcore_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_30591_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_12817_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_24883_00_metrosexual_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_32385_19_normcore_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64460, 파일: W_17616_70_hippie_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64460, 파일: W_24685_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64460, 파일: W_29693_19_normcore_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64460, 파일: W_26227_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 사용자 97/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64598, 파일: W_34952_19_genderless_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64598, 파일: W_41341_19_lounge_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64598, 파일: W_45386_00_oriental_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64598, 파일: W_30431_80_powersuit_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64598, 파일: W_47967_19_normcore_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64598, 파일: W_28338_80_powersuit_W.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64598, 파일: W_19335_50_feminine_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64598, 파일: W_20593_70_punk_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64598, 파일: W_11262_00_oriental_W.jpg, 예측: 비선호, 실제: 비선호
# 사용자 98/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64662, 파일: W_46459_80_powersuit_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64662, 파일: W_08691_10_sportivecasual_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64662, 파일: W_26803_70_hippie_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64662, 파일: W_34808_10_sportivecasual_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64662, 파일: W_36130_00_ecology_W.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64662, 파일: W_43283_90_grunge_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64662, 파일: W_22623_00_cityglam_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64662, 파일: W_33876_60_popart_W.jpg, 예측: 선호, 실제: 비선호
# 검증 결과 - 사용자: 64662, 파일: W_47546_60_minimal_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64662, 파일: W_18391_50_classic_W.jpg, 예측: 비선호, 실제: 비선호
# 사용자 99/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 7658, 파일: W_04927_50_feminine_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 7658, 파일: W_09731_19_genderless_W.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 7658, 파일: W_01234_10_sportivecasual_W.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 7658, 파일: W_13535_80_powersuit_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 7658, 파일: W_19003_50_feminine_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 7658, 파일: W_05312_80_bodyconscious_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 7658, 파일: W_02345_60_space_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 7658, 파일: W_14923_60_minimal_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 7658, 파일: W_13688_90_hiphop_W.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 7658, 파일: W_10510_60_space_W.jpg, 예측: 비선호, 실제: 비선호
# 사용자 100/100의 Validation 이미지 예측 중...
# 검증 결과 - 사용자: 64295, 파일: W_12803_70_hippie_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64295, 파일: W_33329_50_ivy_M.jpg, 예측: 비선호, 실제: 선호
# 검증 결과 - 사용자: 64295, 파일: W_30027_50_ivy_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64295, 파일: W_28563_90_hiphop_M.jpg, 예측: 선호, 실제: 선호
# 검증 결과 - 사용자: 64295, 파일: W_16374_10_sportivecasual_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_25761_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_15729_90_hiphop_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_32314_19_normcore_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_23900_50_ivy_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_27750_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_24598_80_bold_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_04237_60_mods_M.jpg, 예측: 비선호, 실제: 비선호
# 검증 결과 - 사용자: 64295, 파일: W_31478_19_normcore_M.jpg, 예측: 비선호, 실제: 비선호
# 모든 Validation 이미지에 대한 예측 완료.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

# 예측 결과를 데이터프레임으로 변환
results_df = pd.DataFrame(results)
true_labels = results_df['true_label'].map({'선호': 1, '비선호': 0})
predicted_labels = results_df['predicted_label'].map({'선호': 1, '비선호': 0})

# 성능 지표 계산
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

# 성능 결과 출력
print("----- Model Performance Metrics -----")
print(f"Accuracy (정확도): {accuracy:.2f}")
print(f"Precision (정밀도): {precision:.2f}")
print(f"Recall (재현율): {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print("-------------------------------------")
# Out:
# ----- Model Performance Metrics -----
# Accuracy (정확도): 0.67
# Precision (정밀도): 0.60
# Recall (재현율): 0.51
# F1 Score: 0.55
# -------------------------------------
